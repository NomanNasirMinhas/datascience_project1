# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('./pak_wdi.csv')
#df.head()

# %%
del df['Country Name']
del df['Country Code']
df_trans=df.T
df_trans.head()
# Out:
#                                                              0     \
# Indicator Name  Access to clean fuels and technologies for coo...
# Indicator Code                                     EG.CFT.ACCS.ZS
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
#
#                                                    1     \
# Indicator Name  Access to electricity (% of population)
# Indicator Code                           EG.ELC.ACCS.ZS
# 1960                                                NaN
# 1961                                                NaN
# 1962                                                NaN
#
#                                                              2     \
# Indicator Name  Access to electricity, rural (% of rural popul...
# Indicator Code                                  EG.ELC.ACCS.RU.ZS
# ...

# %%
num_rows = df_trans.shape[0] #Provide the number of rows in the dataset
num_cols = df_trans.shape[1] #Provide the number of columns in the dataset
print("Rows = ",num_rows)
print("Columns = ",num_cols)
# Out:
# Rows =  62
# Columns =  1429

# %%
cols_list=[]
for name in range(cols):
    #print(df_trans[name][0])
    cols_list.append(df_trans[name][0])

# %%
df_trans.columns = cols_list
df_trans.head()
# Out:
#                Access to clean fuels and technologies for cooking (% of population)  \
# Indicator Name  Access to clean fuels and technologies for coo...
# Indicator Code                                     EG.CFT.ACCS.ZS
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
#
#                 Access to electricity (% of population)  \
# Indicator Name  Access to electricity (% of population)
# Indicator Code                           EG.ELC.ACCS.ZS
# 1960                                                NaN
# 1961                                                NaN
# 1962                                                NaN
#
#                Access to electricity, rural (% of rural population)  \
# Indicator Name  Access to electricity, rural (% of rural popul...
# Indicator Code                                  EG.ELC.ACCS.RU.ZS
# ...

# %%
cleaned_data = df_trans.drop(["Indicator Name", "Indicator Code"], axis=0)
cleaned_data.head()
# Out:
#      Access to clean fuels and technologies for cooking (% of population)  \
# 1960                                                NaN
# 1961                                                NaN
# 1962                                                NaN
# 1963                                                NaN
# 1964                                                NaN
#
#      Access to electricity (% of population)  \
# 1960                                     NaN
# 1961                                     NaN
# 1962                                     NaN
# 1963                                     NaN
# 1964                                     NaN
#
#      Access to electricity, rural (% of rural population)  \
# 1960                                                NaN
# 1961                                                NaN
# 1962                                                NaN
# 1963                                                NaN
# ...

# %%
mil_data=cleaned_data['Military expenditure (current USD)'].tolist()
gdp_data=cleaned_data['GDP (current US$)'].tolist()

# %%
indexNamesArr = cleaned_data.index.values
row_labels = list(indexNamesArr)

# %%
#print(mil_data)
#print("------------------------------------\n\n\n\n")
#print(gdp_data)
plt.plot(row_labels, gdp_data)
plt.plot(row_labels, mil_data)
ax = plt.axes()
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())
plt.xlabel("Year 1960 - 2019")
plt.ylabel("USD 1e11")
plt.title("Pak's GDP vs Military Spending from 1960-2019")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# Text(0.5, 1.0, "Pak's GDP vs Military Spending from 1960-2019")

# %%
population_data=cleaned_data['Population, total'].tolist()
inflation_data=cleaned_data['Inflation, consumer prices (annual %)'].tolist()

# %%
plt.plot(population_data, inflation_data)
#plt.plot(row_labels, inflation_data)
ax = plt.axes()
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())
plt.xlabel("Population of Pakistan from 1960-2019")
plt.ylabel("Inflation %")
plt.title("Relationship Between Population & Inflation")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0.5, 1.0, 'Relationship Between Population & Inflation')

# %%
expend_data=cleaned_data['Gross national expenditure (current US$)'].tolist()

# %%
plt.plot(row_labels, gdp_data)
plt.plot(row_labels, expend_data)
ax = plt.axes()
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())
plt.xlabel("Year 1960 - 2019")
plt.ylabel("USD 1e11")
plt.title("Pak's GDP vs Govt. Spending from 1960-2019")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0.5, 1.0, "Pak's GDP vs Govt. Spending from 1960-2019")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
# %matplotlib inline

# %%
X = cleaned_data[['Exports of goods and services (current US$)', 'Gross national expenditure (current US$)', 'Gross savings (current US$)', 'Imports of goods and services (current US$)','Military expenditure (current USD)','Personal remittances, received (current US$)']]
y = cleaned_data['GDP (current US$)']

cleaned_X = X.dropna(axis=0)
cleaned_y = y.dropna(axis=0)

# %%
#cleaned_y = cleaned_y.head(43)
print(cleaned_y.shape)
print(cleaned_X.shape)
# Out:
# (59,)
# (43, 6)

# %%
cleaned_y = cleaned_y.head(43)
print(cleaned_y.shape)
print(cleaned_X.shape)
# Out:
# (43,)
# (43, 6)

# %%
X_train, X_test, y_train, y_test = train_test_split(cleaned_X, cleaned_y, test_size=.15, random_state=50)
lm_model =LinearRegression(normalize=True)

# %%
lm_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
prediction = lm_model.predict(cleaned_X)
prediction = pd.Series(prediction)
prediction.size
#prediction = prediction.reshape(-1,1)
# Out:
# 43

# %%
#plt.scatter(gdp_data[:13], prediction, color = "red")
plt.plot(row_labels[:43], prediction)
plt.plot(row_labels[:43], cleaned_y)
ax = plt.axes()
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())
plt.xlabel("Years")
plt.ylabel("USD 1e11")
plt.title("Pakistan's GDP Model Prediction")
figure(num=None, figsize=(20,20), dpi=180)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.
